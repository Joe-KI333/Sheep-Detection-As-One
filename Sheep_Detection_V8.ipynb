# %%
# !nvidia-smi
# Out:
# Wed Feb  8 07:16:04 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    30W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
project = rf.workspace("riis").project("aerial-sheep")
dataset = project.version(1).download("yolov8")
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.0/49.0 KB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 8.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9674 sha256=e4a93ece671e1b0c426d2f1c3846e2d9edd8dee794becdaef3f12393de4797bd
#   Stored in directory: /root/.cache/pip/wheels/bd/a8/c3/3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.9
#     Uninstalling pyparsing-3.0.9:
#       Successfully uninstalled pyparsing-3.0.9
#   Attempting uninstall: cycler
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data=/content/datasets/Aerial-Sheep-1/data.yaml epochs=10 imgsz=600 batch=4
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 7.22MB/s]
#
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data=/content/datasets/Aerial-Sheep-1/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/Aerial-Sheep-1/valid/labels.cache... 350 images, 1 backgrounds, 0 corrupt: 100% 350/350 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 22/22 [00:12<00:00,  1.73it/s]
#                    all        350      11337      0.954      0.927      0.958      0.575
# Speed: 2.5ms pre-process, 4.2ms inference, 0.0ms loss, 2.1ms post-process per image

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/datasets/Aerial-Sheep-1/test/images imgsz=416 line_thickness=1 save=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# image 1/174 /content/datasets/Aerial-Sheep-1/test/images/DJI_0004_0262_jpg.rf.14f93587a02be481b46b466ea33580a9.jpg: 416x416 20 sheeps, 11.6ms
# image 2/174 /content/datasets/Aerial-Sheep-1/test/images/DJI_0004_0285_jpg.rf.3437cf4895f48307e807216955ab9d02.jpg: 416x416 23 sheeps, 12.1ms
# image 3/174 /content/datasets/Aerial-Sheep-1/test/images/DJI_0004_0290_jpg.rf.414563acc6568f6a8e9cccbae5ea39e6.jpg: 416x416 13 sheeps, 12.9ms
# image 4/174 /content/datasets/Aerial-Sheep-1/test/images/DJI_0005_0002_jpg.rf.0a5178c93661aded7723bf47e2e423b4.jpg: 416x416 19 sheeps, 12.1ms
# image 5/174 /content/datasets/Aerial-Sheep-1/test/images/DJI_0005_0014_jpg.rf.c677eebcf83e27a7404c736c21bef075.jpg: 416x416 23 sheeps, 11.5ms
# ...

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source=/content/drive/MyDrive/SheepDetection/sheep.mp4 imgsz=600 line_thickness=1 save=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# WARNING ⚠️ --img-size [600] must be multiple of max stride 32, updating to [608]
# video 1/1 (1/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 9.0ms
# video 1/1 (2/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 9.7ms
# video 1/1 (3/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 8.9ms
# video 1/1 (4/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 10.3ms
# video 1/1 (5/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 13.4ms
# video 1/1 (6/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 8.9ms
# video 1/1 (7/547) /content/drive/MyDrive/SheepDetection/sheep.mp4: 608x608 20 sheeps, 8.8ms
# ...
